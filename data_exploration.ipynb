# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sb

# %%
df = pd.read_json('data/fishbit_data_cleaned.json')

# %%
df = df[['timestamp', 'pH', 'Temperature', 'Salinity']]

# %%
df.head()
# Out:
#                 timestamp    pH  Temperature  Salinity
# 0 2015-12-09 02:36:56.647  8.19        76.55    1.0308
# 1 2015-12-09 02:41:56.705  8.20        76.66    1.0311
# 2 2015-12-09 02:46:56.856  8.19        76.66    1.0313
# 3 2015-12-09 02:51:56.826  8.19        76.78    1.0316
# 4 2015-12-09 02:56:56.811  8.19        76.78    1.0317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24324 entries, 0 to 24323
# Data columns (total 4 columns):
# timestamp      24324 non-null datetime64[ns]
# pH             24324 non-null float64
# Temperature    24324 non-null float64
# Salinity       24324 non-null float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 950.2 KB

# %%
df.index = df['timestamp']

# %%
del df['timestamp']

# %%
df.head()
# Out:
#                            pH  Temperature  Salinity
# timestamp
# 2015-12-09 02:36:56.647  8.19        76.55    1.0308
# 2015-12-09 02:41:56.705  8.20        76.66    1.0311
# 2015-12-09 02:46:56.856  8.19        76.66    1.0313
# 2015-12-09 02:51:56.826  8.19        76.78    1.0316
# 2015-12-09 02:56:56.811  8.19        76.78    1.0317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24324 entries, 2015-12-09 02:36:56.647000 to 2016-04-23 02:37:12.748000
# Data columns (total 3 columns):
# pH             24324 non-null float64
# Temperature    24324 non-null float64
# Salinity       24324 non-null float64
# dtypes: float64(3)
# memory usage: 760.1 KB

# %%
df['2016-01'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2364 entries, 2016-01-06 15:39:21.868000 to 2016-01-31 23:59:07.650000
# Data columns (total 3 columns):
# pH             2364 non-null float64
# Temperature    2364 non-null float64
# Salinity       2364 non-null float64
# dtypes: float64(3)
# memory usage: 73.9 KB

# %%
df.tail()
# Out:
#                            pH  Temperature  Salinity
# timestamp
# 2016-04-23 02:17:08.698  8.12        75.97    1.0235
# 2016-04-23 02:22:09.604  8.11        75.98    1.0235
# 2016-04-23 02:27:10.594  8.11        75.90    1.0235
# 2016-04-23 02:32:11.730  8.11        75.90    1.0234
# 2016-04-23 02:37:12.748  8.10        75.89    1.0234

# %%
april_20 = df['4/20/16']

# %%
april_20
# Out:
#                            pH  Temperature  Salinity
# timestamp
# 2016-04-20 00:01:43.294  8.11        77.68    1.0231
# 2016-04-20 00:06:44.308  8.10        77.68    1.0231
# 2016-04-20 00:11:45.389  8.11        77.68    1.0231
# 2016-04-20 00:16:46.413  8.11        77.68    1.0231
# 2016-04-20 00:21:47.395  8.11        77.68    1.0231
# 2016-04-20 00:26:48.484  8.11        77.68    1.0231
# 2016-04-20 00:31:49.510  8.11        77.69    1.0231
# 2016-04-20 00:36:50.439  8.11        77.69    1.0231
# 2016-04-20 00:41:51.515  8.11        77.68    1.0231
# 2016-04-20 00:46:52.539  8.10        77.70    1.0231
# 2016-04-20 00:51:53.463  8.11        77.72    1.0231
# 2016-04-20 00:56:54.454  8.11        77.68    1.0231
# 2016-04-20 01:01:55.569  8.11        77.68    1.0231
# 2016-04-20 01:06:56.588  8.10        77.69    1.0231
# 2016-04-20 01:11:57.580  8.11        77.69    1.0231
# 2016-04-20 01:16:58.592  8.11        77.70    1.0231
# ...

# %%
april = df['4/2016']

# %%
april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6288 entries, 2016-04-01 00:02:17.815000 to 2016-04-23 02:37:12.748000
# Data columns (total 3 columns):
# pH             6288 non-null float64
# Temperature    6288 non-null float64
# Salinity       6288 non-null float64
# dtypes: float64(3)
# memory usage: 196.5 KB

# %%
april['pH'].resample('D').mean().plot()

# %%
april['Temperature'].resample('D').mean().plot()

# %%
april['Salinity'].resample('D').mean().plot()

# %%
df.resample('D').mean().plot()

# %%
df['pH'].resample('D').mean().plot()

# %%
df['Temperature'].resample('D').mean().plot()

# %%
df['Salinity'].resample('D').mean().plot()

# %%
df['pH'].plot()

# %%
df['Salinity'].plot()

# %%
df['Temperature'].plot()

# %%
df.index.week
# Out:
# array([50, 50, 50, ..., 16, 16, 16], dtype=int32)

# %%
df['pH'].groupby(df.index.week).plot()
# Out:
# 1     Axes(0.125,0.2;0.775x0.7)
# 2     Axes(0.125,0.2;0.775x0.7)
# 4     Axes(0.125,0.2;0.775x0.7)
# 5     Axes(0.125,0.2;0.775x0.7)
# 6     Axes(0.125,0.2;0.775x0.7)
# 7     Axes(0.125,0.2;0.775x0.7)
# 8     Axes(0.125,0.2;0.775x0.7)
# 9     Axes(0.125,0.2;0.775x0.7)
# 11    Axes(0.125,0.2;0.775x0.7)
# 12    Axes(0.125,0.2;0.775x0.7)
# 13    Axes(0.125,0.2;0.775x0.7)
# 14    Axes(0.125,0.2;0.775x0.7)
# 15    Axes(0.125,0.2;0.775x0.7)
# 16    Axes(0.125,0.2;0.775x0.7)
# 50    Axes(0.125,0.2;0.775x0.7)
# 51    Axes(0.125,0.2;0.775x0.7)
# 52    Axes(0.125,0.2;0.775x0.7)
# 53    Axes(0.125,0.2;0.775x0.7)
# Name: pH, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24324 entries, 2015-12-09 02:36:56.647000 to 2016-04-23 02:37:12.748000
# Data columns (total 3 columns):
# pH             24324 non-null float64
# Temperature    24324 non-null float64
# Salinity       24324 non-null float64
# dtypes: float64(3)
# memory usage: 760.1 KB

# %%
df_weekly = df.groupby(df.index.week)

# %%
df_weekly['pH'].resample('H').mean().plot()

# %%
df['4/2016']['pH'].plot()

# %%
df['4/2016'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6288 entries, 2016-04-01 00:02:17.815000 to 2016-04-23 02:37:12.748000
# Data columns (total 3 columns):
# pH             6288 non-null float64
# Temperature    6288 non-null float64
# Salinity       6288 non-null float64
# dtypes: float64(3)
# memory usage: 196.5 KB

# %%
df['4/1/2016':'4/7/2016'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1981 entries, 2016-04-01 00:02:17.815000 to 2016-04-07 23:58:05.398000
# Data columns (total 3 columns):
# pH             1981 non-null float64
# Temperature    1981 non-null float64
# Salinity       1981 non-null float64
# dtypes: float64(3)
# memory usage: 61.9 KB

# %%
df['4/1/2016':'4/7/2016']['pH'].resample('H').mean().plot()

# %%
g = sb.FacetGrid(df['4/1/2016':'4/7/2016']['pH'].resample('H').mean())

# %%
april_20['pH'].resample('30T').mean().plot()

# %%
sb.tsplot(april_20['pH'])

# %%
april_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 285 entries, 2016-04-20 00:01:43.294000 to 2016-04-20 23:56:56.151000
# Data columns (total 3 columns):
# pH             285 non-null float64
# Temperature    285 non-null float64
# Salinity       285 non-null float64
# dtypes: float64(3)
# memory usage: 8.9 KB

# %%
df['4/1/16':'4/7/2016']['pH'].resample('30T').mean().plot()

# %%
df['4/1/16':'4/7/2016']['Temperature'].resample('30T').mean().plot()

# %%
df['4/1/16':'4/7/2016']['Salinity'].resample('30T').mean().plot()

# %%
df['4/1/16':'4/7/2016'][['pH']].resample('30T').mean().A.plot()
df['4/1/16':'4/7/2016'][['Temperature']].resample('30T').mean().B.plot(secondary_y=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-a2ddc4c59699> in <module>()
# ----> 1 df['4/1/16':'4/7/2016'][['pH']].resample('30T').mean().A.plot()
#       2 df['4/1/16':'4/7/2016'][['Temperature']].resample('30T').mean().B.plot(secondary_y=True)
#
# /Users/Bradley/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'A'

# %%
df_week = df['4/1/16':'4/7/2016'].resample('30T').mean()

# %%
df_week.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 336 entries, 2016-04-01 00:00:00 to 2016-04-07 23:30:00
# Freq: 30T
# Data columns (total 3 columns):
# pH             336 non-null float64
# Temperature    336 non-null float64
# Salinity       336 non-null float64
# dtypes: float64(3)
# memory usage: 10.5 KB

# %%
df_week.pH.plot()
df_week.Temperature.plot(secondary_y=True)

# %%
ph = df_week.pH.plot(legend=True)
ph.set_ylabel('pH')
ax = df_week.Temperature.plot(secondary_y=True, legend=True)
ax.set_ylabel('Temperature')

# %%
ph = df_week.pH.plot(legend=True)
ph.set_ylabel('pH')
ax = df_week.Salinity.plot(secondary_y=True, legend=True)
ax.set_ylabel('Salinity')

# %%
ph = df_week.Temperature.plot(legend=True)
ph.set_ylabel('Temperature')
ax = df_week.Salinity.plot(secondary_y=True, legend=True)
ax.set_ylabel('Salinity')

# %%
df_month = df['3/23/16':'4/23/2016'].resample('12H').mean()

# %%
df_month.pH.plot()

# %%
df_month.Temperature.plot()

# %%
df_month.Salinity.plot()

# %%
df_month.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000    -0.008568  0.293420
# Temperature -0.008568     1.000000 -0.018332
# Salinity     0.293420    -0.018332  1.000000

# %%
df_week.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000     0.330532 -0.005272
# Temperature  0.330532     1.000000 -0.605622
# Salinity    -0.005272    -0.605622  1.000000

# %%
df.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000     0.095916  0.248770
# Temperature  0.095916     1.000000 -0.060477
# Salinity     0.248770    -0.060477  1.000000

# %%
april_20.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000     0.467399  0.099716
# Temperature  0.467399     1.000000 -0.732159
# Salinity     0.099716    -0.732159  1.000000

# %%
day = april_20.resample('30T').mean()

# %%
day.pH.plot()

# %%
day.Temperature.plot()

# %%
day.Salinity.plot()

# %%
april_20.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000     0.467399  0.099716
# Temperature  0.467399     1.000000 -0.732159
# Salinity     0.099716    -0.732159  1.000000

# %%
day.corr()
# Out:
#                    pH  Temperature  Salinity
# pH           1.000000     0.466646  0.111916
# Temperature  0.466646     1.000000 -0.765664
# Salinity     0.111916    -0.765664  1.000000
